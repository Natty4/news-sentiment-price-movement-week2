# %% [markdown]
# ## 🟩 1. Setup & Import Libraries

# %%
import sys, pathlib
sys.path.append(str(pathlib.Path.cwd().parent / 'src'))

from utils import FinancialNewsEDA
import pandas as pd

# %% [markdown]
# ## 🟩 2. Load and Prepare Data

# %%
# Load dataset

df = pd.read_csv("../data/raw_analyst_ratings.csv")
eda = FinancialNewsEDA(df)

# %% [markdown]
# ## 🟩 3. Descriptive Statistics

# %%
# Headline Length Distribution


eda.plot_headline_length_dist()

# %%
eda.compare_headline_stats()
# Out:
# c:\Users\hp\Documents\Learning\Remote\10Academy\W1\src\utils.py:89: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=self.df, x="is_benzinga", y="headline_length", palette="Set2")
# c:\Users\hp\Documents\Learning\Remote\10Academy\W1\src\utils.py:94: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=self.df, x="is_benzinga", y="word_count", palette="Set2")

# %%
# Summary statistics
eda.summary()
# Out:
# Total articles: 55987
# Total unique publishers: 225
# Time range: 2011-04-27 21:01:48-04:00 to 2020-06-11 17:12:35-04:00
# Missing values:
#  Unnamed: 0               0
# headline                 0
# url                      0
# publisher                0
# date                     0
# stock                    0
# headline_length          0
# word_count               0
# hour                     0
# weekday                  0
# domain               54788
# publisher_grouped        0
# is_benzinga              0
# dtype: int64

# %% [markdown]
# ## 🟩 4. Text Analysis (Topic Modeling)

# %%
# Basic TF-IDF Topic Clustering (on headlines)

eda.topic_modeling()
# Out:
# 🧠 Topics discovered:
# Topic 1: hit, 52, week, stocks, lows, thursday, highs
# Topic 2: moving, session, market, mid, day, stocks, pre
# Topic 3: movers, biggest, yesterday, new, set, low, friday
# Topic 4: price, target, maintains, raises, lowers, buy, neutral
# Topic 5: estimate, eps, sales, q1, yoy, beats, beat

# %%
eda.display_top_keywords()
# Out:
# 🔷 Benzinga Keywords:
# the: 7756
# shares: 6248
# trading: 6101
# are: 5737
# stocks: 5092
# companies: 4562
# several: 4539
# and: 4526
# from: 4374
# eps: 3911
# estimate: 3647
# week: 3602
# higher: 3534
# sales: 3487
# which: 2963
#
# 🔶 Other Publisher Keywords:
# stocks: 7702
# for: 5571
# week: 5427
# that: 4996
# hit: 4746
# the: 3533
# price: 3262
# lows: 3229
# target: 3133
# from: 3026
# market: 2954
# mid: 2914
# etfs: 2677
# thursday: 2482
# biggest: 2354

# %% [markdown]
# ## 🟩 5. Time Series & Publishing Patterns

# %%
# Articles by Hour of Day

eda.plot_articles_by_hour()
# Out:
# c:\Users\hp\Documents\Learning\Remote\10Academy\W1\src\utils.py:56: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="hour", data=self.df, palette="viridis")

# %%
# Articles by Day of Week

eda.plot_articles_by_weekday()

# %%
eda.compare_publication_time()

# %% [markdown]
# ## 🟩 6. Publisher & Date Analysis

# %%
eda.plot_top_publishers()
# Out:
# c:\Users\hp\Documents\Learning\Remote\10Academy\W1\src\utils.py:79: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_groups.values, y=top_groups.index, palette="viridis")
# publisher_grouped
# Benzinga            21567
# Lisa Levin          12408
# ETF Professor        4362
# Paul Quintaro        4212
# Vick Meyer           2128
# Charles Gross        1790
# Hal Lindon           1470
# benzinga.com         1196
# Eddie Staley         1003
# Shanthi Rexaline      887
# Name: count, dtype: int64

# %%
eda.compute_sentiment()
eda.plot_sentiment_comparison()
# Out:
# c:\Users\hp\Documents\Learning\Remote\10Academy\W1\src\utils.py:133: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=self.df, x="is_benzinga", y="sentiment", palette="coolwarm")

# %%
# Wrap-Up Summary
eda.summary()
# Out:
# Total articles: 55987
# Total unique publishers: 225
# Time range: 2011-04-27 21:01:48-04:00 to 2020-06-11 17:12:35-04:00
# Missing values:
#  Unnamed: 0               0
# headline                 0
# url                      0
# publisher                0
# date                     0
# stock                    0
# headline_length          0
# word_count               0
# hour                     0
# weekday                  0
# domain               54788
# publisher_grouped        0
# is_benzinga              0
# sentiment                0
# dtype: int64
